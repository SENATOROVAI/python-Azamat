# %% [markdown]
# Взаимодействие с командой происходит через общий форкнутый репозиторий, алгоритм действий;
# 1. Заходим в Сенаторов тим и изучаем участников, от которых будем форкаться;
# 2. Выбираем коллегу и форкаем понравившейся репозиторий, если не знаем что форкать, пишем в чат: "@Посоветуй репу для код ревью";
# 3. После форка создаем дев ветку;
# 4. Пишем в чатик дай права и ссылку на репу;
# 5. Когда выдали права, совершаем комиты с комментариями где непонятно, комиты можно делать, но команда не смотжет помочь;
# 6. Пишешь в чат кодревью, @Ник и пишешь прими гит пул и ссылочку на репу СенаторовAI
